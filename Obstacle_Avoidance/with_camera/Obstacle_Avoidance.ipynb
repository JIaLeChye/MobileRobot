# %% [markdown]
# # Obstacle Avoidance with Camera using OpenCV and Ultrasonic Sensors
# **Full Coding available at [Obstacle_Avoidance.py](Obstacle_Avoidance.py)**
# <br>
# This is the documentation for Obstacle Avoidance with Camera integration using OpenCV, ultrasonic sensors, and multi-threading.
#
# This advanced robotics project combines computer vision with ultrasonic sensor-based obstacle detection. The system uses multiple ultrasonic sensors (left, front, right) to detect obstacles while simultaneously capturing and displaying live camera feed using multi-threading. This allows for enhanced situational awareness and more sophisticated navigation decisions.
#
# ***Libraries Used In The Script***
# - threading - For concurrent execution of camera capture and obstacle detection
# - OpenCV (cv2) - For image processing and display
# - Picamera2 - Raspberry Pi camera interface
# - libcamera - Camera control and autofocus
# - Ultrasonic_sens - Custom ultrasonic sensor library
# - RPi_Robot_Hat_Lib - Custom robot control library
# - time - For timing operations and delays

# %% [markdown]
# ## Installing Libraries & Dependencies
# - Built-in Libraries:
#     - Picamera2 (Pre-installed on Raspberry Pi OS)
#     - libcamera (Pre-installed on Raspberry Pi OS)
#     - time (Built-in Python library)
#     - threading (Built-in Python library)
# - Libraries Requiring Installation:
#     - OpenCV
#     - Ultrasonic_sens (Custom library)
#     - RPi_Robot_Hat_Lib (Custom library)
#
# ## Installing Required Libraries
# 1. **OpenCV** [OpenCV.org](https://docs.opencv.org/4.x/d2/de6/tutorial_py_setup_in_ubuntu.html)
#     - In the terminal type: `pip install opencv-python`
#     - To verify installation, in a Python file type: <br>
#     `import cv2` <br>
#     `print(cv2.__version__)`
#     - This will print the version of OpenCV library installed
#
# 2. **Custom Libraries**
#     - **Ultrasonic_sens**: Custom library for multi-sensor ultrasonic distance measurement
#     - **RPi_Robot_Hat_Lib**: Custom robot control library for motor movement and servo control
#     - Install according to your robot hardware setup instructions

# %% [markdown]
# ## Let's Start Coding !
# ### 1. Import all the required libraries
# - threading - For concurrent execution of camera and obstacle detection tasks
# - OpenCV (cv2) - For image processing and live camera feed display
# - Picamera2 - For Raspberry Pi camera control and image capture
# - libcamera - For camera configuration and autofocus control
# - Ultrasonic_sens - For ultrasonic sensor distance measurements
# - RPi_Robot_Hat_Lib - For robot motor control and servo positioning
# - time - For timing operations and movement delays

# %%
import threading 
import cv2 
from picamera2 import Picamera2
from Ultrasonic_sens import Ultrasonic 
from RPi_Robot_Hat_Lib import RobotController 
import time 
from libcamera import controls, Transform

# %% [markdown]
# ### 2. Hardware Components and Configuration Setup
#
# This setup initializes all hardware components and configures system parameters for optimal obstacle avoidance performance.
#
# - **Setup Name**: Hardware and System Configuration
#
#
# - **Usage**:
#   - Initialize ultrasonic sensor system for multi-directional distance measurement:
#
#     ```python
#     ultrasonic = Ultrasonic()
#     ```
#   - Initialize robot motor and servo control system:
#
#     ```python
#     Motor = RobotController()
#     ```
#   - Configure servo channels and position camera for optimal field of view:
#
#     ```python
#     vertical = 2      # Servo channel for vertical camera movement
#     horizontal = 1    # Servo channel for horizontal camera movement
#     Motor.set_servo(vertical, 80)   # Position camera at optimal angle
#     Motor.set_servo(horizontal, 90) # Center horizontal position
#     ```
#   - Set movement parameters and distance thresholds:
#
#     ```python
#     Speed = 30                # Forward movement speed
#     rotation_speed = 20       # Turning speed for obstacle avoidance
#     threshold = 30            # Distance threshold for obstacle detection (cm)
#     min_thresh_dist = 10      # Minimum distance threshold for emergency actions
#     ```
#   - Configure Raspberry Pi camera with proper settings:
#
#     ```python
#     picam2 = Picamera2()
#     picam2.configure(picam2.create_preview_configuration(main={"format": 'RGB888', "size": (640, 480)},
#                                                         transform=Transform(vflip=1)))
#     picam2.start()
#     picam2.set_controls({"AfMode": controls.AfModeEnum.Continuous})
#     ```
#   - Set up multi-threading components for concurrent operations:
#
#     ```python
#     frame_lock = threading.Lock()        # Protects shared camera frame data
#     shutdown_event = threading.Event()   # Signals system shutdown
#     capture_thread = threading.Thread(target=capture_frame)  # Camera capture thread
#     ```

# %%
ultrasonic = Ultrasonic()
Motor = RobotController()
vertical = 2
horizontal = 1
Motor.set_servo(vertical, 80)
Motor.set_servo(horizontal, 90)

Speed = 30
rotation_speed = 20
threshold = 30 
min_thresh_dist = 10 
picam2 = Picamera2() 
picam2.configure(picam2.create_preview_configuration(main={"format": 'RGB888', "size": (640, 480)},transform=Transform(vflip=1)))
picam2.start()
picam2.set_controls({"AfMode": controls.AfModeEnum.Continuous})
frame_lock = threading.Lock()
capture_thread = threading.Thread(target=capture_frame)  # Start the capture frame thread
shutdown_event = threading.Event()

# %% [markdown]
# ### 3. The Camera Capture Function `capture_frame()`
#
# This function continuously captures camera frames and displays them using OpenCV in a separate thread.
#
# - **Function Name**: `capture_frame`
#
# - **Usage**:
#   - Access global variables for camera control and threading:
#     ```python
#     global picam2, frame_lock, shutdown_event
#     ```
#   - Run continuous capture loop until shutdown signal:
#     ```python
#     while not shutdown_event.is_set():
#     ```
#   - Capture frame with thread-safe locking mechanism:
#     ```python
#     with frame_lock:
#         frame = picam2.capture_array()
#     ```
#   - Display captured frame using OpenCV:
#     ```python
#     cv2.imshow("Frame", frame)
#     ```
#   - Handle user input for program termination:
#     ```python
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         shutdown_event.set()  # Signal to stop the program
#         break
#     ```
#   - Clean up OpenCV windows on exit:
#     ```python
#     cv2.destroyAllWindows()  # Cleanup the OpenCV windows
#     ```

# %%
# Capture and Display Frame 
def capture_frame():
    global picam2, frame_lock, shutdown_event
    while not shutdown_event.is_set():
        with frame_lock:
            frame = picam2.capture_array()
        cv2.imshow("Frame", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            shutdown_event.set()  # Signal to stop the program
            break 
    cv2.destroyAllWindows()  # Cleanup the OpenCV windows

# %% [markdown]
# ### 4. The Obstacle Avoidance Function `obstacle_Avoid(left, front, right)`
#
# This function processes ultrasonic sensor data and determines robot movement direction for intelligent obstacle avoidance.
#
# - **Function Name**: `obstacle_Avoid`
#
# - **Parameters**:
#   - `left` *(float)*: Distance reading from left ultrasonic sensor in centimeters
#   - `front` *(float)*: Distance reading from front ultrasonic sensor in centimeters
#   - `right` *(float)*: Distance reading from right ultrasonic sensor in centimeters
#
# - **Usage**:
#   - **Primary obstacle detection** - Front sensor below threshold triggers avoidance:
#     ```python
#     if front < threshold:
#         if front <= min_thresh_dist:
#             print("Reversing")
#             Motor.Backward(Speed)
#     ```
#   - **Emergency reverse** - Both sides blocked with front obstacle:
#     ```python
#     elif left < min_thresh_dist and right < min_thresh_dist:
#         print("Reversing")
#         Motor.Backward(Speed)
#     ```
#   - **Directional avoidance** - Turn away from closest side obstacle:
#     ```python
#     elif left < threshold:
#         print("Turning Right")
#         Motor.move(speed=0, turn=-rotation_speed)
#     elif right < threshold:
#         print("Turning Left")
#         Motor.move(speed=0, turn=rotation_speed)
#     ```
#   - **Side obstacle correction** - Maintain center path when side obstacles detected:
#     ```python
#     elif left < threshold:
#         print("Turning Right")
#         Motor.move(speed=0, turn=-rotation_speed)
#     elif right < threshold:
#         print("Turning Left")
#         Motor.move(speed=0, turn=rotation_speed)
#     ```
#   - **Clear path forward** - Proceed when no obstacles detected:
#     ```python
#     if right > threshold and left > threshold:
#         print("Forward")
#         Motor.Forward(Speed)
#     ```

# %%
def obstacle_Avoid(left, front, right):
    if front < threshold:
        if front <= min_thresh_dist:
            print("Reversing")
            Motor.Backward(Speed)
            time.sleep(0.1)
            Motor.Brake()
        elif left < min_thresh_dist and right < min_thresh_dist:
            print("Reversing")
            Motor.Backward(Speed)
            time.sleep(0.1)
            Motor.Brake()
        elif left < threshold:
            print("Turning Right") 
            Motor.move(speed=0, turn=-rotation_speed)
            time.sleep(0.5)
            Motor.Brake()
        elif right < threshold:
            print("Turning Left") 
            Motor.move(speed=0, turn=rotation_speed)
            time.sleep(0.5)
            Motor.Brake()
        else:
            print("Reversing")
            Motor.Backward(Speed)
            time.sleep(0.1)
            Motor.Brake()
    
    elif left < threshold:
        print("Turning Right")
        Motor.move(speed=0, turn=-rotation_speed)
        time.sleep(1)
        Motor.Brake()
    
    elif right < threshold:
        print("Turning Left") 
        Motor.move(speed=0, turn=rotation_speed)  
        time.sleep(1)
        Motor.Brake()
    
    else:
        if right > threshold and left > threshold:
            print("Forward") 
            Motor.Forward(Speed)
        elif right > threshold:
            print("Turning Right")
            Motor.move(speed=0, turn=-rotation_speed)
            time.sleep(0.1)
            Motor.Brake()
        elif left > threshold:
            print("Turning Left")
            Motor.move(speed=0, turn=rotation_speed)
            time.sleep(0.1)
            Motor.Brake()

# %% [markdown]
# ### 5. The Main Control Function `main()`
#
# This function orchestrates the main program loop, coordinating sensor readings, camera capture, and obstacle avoidance decisions.
#
# - **Function Name**: `main`
# - **Usage**:
#   - Initialize program and start camera capture thread:
#
#     ```python
#     print("Program Started")
#     capture_thread.start()
#     ```
#   - Main control loop - runs until shutdown signal received:
#
#     ```python
#     while not shutdown_event.is_set():
#     ```
#   - Get distance readings from all three ultrasonic sensors:
#
#     ```python
#     left, front, right = ultrasonic.distances()
#     time.sleep(0.1)
#     ```
#   - Validate sensor data and execute obstacle avoidance if valid:
#
#     ```python
#     if left is not None and front is not None and right is not None:
#         print("Left: {:.2f}".format(left))
#         print("Front: {:.2f}".format(front))
#         print("Right: {:.2f}".format(right))
#         obstacle_Avoid(left, front, right)
#         time.sleep(0.1)
#     ```
#   - Handle invalid sensor data with safety brake:
#
#     ```python
#     else:
#         print("No data received")
#         Motor.Brake()
#         time.sleep(1)
#     ```

# %%
def main(): 
    print("Program Started")
    capture_thread.start()
    while not shutdown_event.is_set():
        # enc.encoder()
        left, front, right = ultrasonic.distances()
        time.sleep(0.1)
        if left is not None and front is not None and right is not None: 
            print("Left: {:.2f}".format(left)) 
            print("Front: {:.2f}".format(front))
            print("Right: {:.2f}".format(right)) 
            print(" ")
            obstacle_Avoid(left, front, right)
            time.sleep(0.1)
        else:
            print("No data received")
            Motor.Brake()
            time.sleep(1)

# %% [markdown]
# ### 6. Program Execution and Cleanup Workflow
#
# This workflow handles program startup, execution, and graceful shutdown with proper resource cleanup.
#
# - **Workflow Name**: Program Execution and Error Handling
#
#
# - **Usage**:
#   - **Main program execution** - Start the main control function:
#
#     ```python
#     try:
#         if __name__ == "__main__":
#             main()
#     ```
#   - **Keyboard interrupt handling** - Graceful shutdown on Ctrl+C:
#
#     ```python
#     except KeyboardInterrupt:
#         shutdown_event.set()
#         Motor.cleanup()
#         print("Program Terminated")
#     ```
#   - **Final cleanup** - Ensure all resources are properly released:
#
#     ```python
#     finally:
#         shutdown_event.set()        # Signal all threads to stop
#         capture_thread.join()       # Wait for camera thread to finish
#         cv2.destroyAllWindows()     # Close all OpenCV windows
#         exit()                      # Exit program
#         print("Program Terminated")
#     ```

# %%
try:
    if __name__ == "__main__":
        main()
            

except KeyboardInterrupt:
    shutdown_event.set()
    Motor.cleanup()
    print("Program Terminated")

finally: 
    shutdown_event.set()
    capture_thread.join()
    cv2.destroyAllWindows()
    exit()
    print("Program Terminated")
