# %% [markdown]
# # Obstacle Avoidance using Ultrasonic Sensors
# **Full Coding available at [Obstacle_Avoidance.py](Obstacle_Avoidance.py)**
# <br>
# This is the documentation for Obstacle Avoidance using multiple ultrasonic sensors without camera integration.
#
# This robotics project demonstrates autonomous navigation using ultrasonic sensor-based obstacle detection. The system uses three ultrasonic sensors (left, front, right) to detect obstacles and implements intelligent decision-making algorithms to navigate around them. This streamlined approach focuses purely on sensor-based navigation without the complexity of computer vision.
#
# ***Libraries Used In The Script***
# - Ultrasonic_sens - Custom ultrasonic sensor library for multi-sensor distance measurement
# - RPi_Robot_Hat_Lib - Custom robot control library for motor movement
# - time - For timing operations and movement delays

# %% [markdown]
# ## Installing Libraries & Dependencies
# - Built-in Libraries:
#     - time (Built-in Python library)
# - Custom Libraries:
#     - Ultrasonic_sens (Custom ultrasonic sensor library)
#     - RPi_Robot_Hat_Lib (Custom robot control library)
#
# ## Custom Library Information
# **All the libraries used are custom-made libraries designed specifically for this robot platform:**
#
# 1. **Ultrasonic_sens**
#     - Custom library for multi-sensor ultrasonic distance measurement
#     - Provides simultaneous readings from left, front, and right ultrasonic sensors
#     - Handles sensor communication and data validation
#     - Install according to your robot hardware setup instructions
#
# 2. **RPi_Robot_Hat_Lib**
#     - Custom robot control library for motor movement and direction control
#     - Provides easy-to-use functions for forward, backward, turning, and braking
#     - Designed specifically for Robot HAT hardware
#     - Install according to your robot hardware setup instructions
#
# 3. **time**
#     - Built-in Python library used for delays and timing operations
#     - No installation required

# %% [markdown]
# ## Let's Start Coding !
# ### 1. Import all the required libraries
# - Ultrasonic_sens - For multi-sensor ultrasonic distance measurements from left, front, and right sensors
# - RPi_Robot_Hat_Lib - For robot motor control and movement functions
# - time - For timing operations and movement delays

# %%
from Ultrasonic_sens import Ultrasonic 
from RPi_Robot_Hat_Lib import RobotController
import time

# %% [markdown]
# ### 2. Hardware Components and Configuration Setup
#
# This setup initializes the ultrasonic sensors and robot controller, and defines key parameters for obstacle detection and navigation behavior.
#
# - **Setup Name**: Hardware Components and Configuration
#
# - **Usage**:
#   - Initialize multi-sensor ultrasonic measurement system:
#     ```python
#     ultrasonic = Ultrasonic()
#     ```
#   - Initialize robot motor control system:
#     ```python
#     Motor = RobotController()
#     ```
#   - Configure movement speed parameters for different maneuvers:
#     ```python
#     Speed = 40              # Forward and backward movement speed
#     rotation_speed = 30     # Turning speed for obstacle avoidance maneuvers
#     ```
#   - Set distance thresholds for obstacle detection and emergency actions:
#     ```python
#     threshold = 20          # Distance threshold for obstacle detection (cm)
#     min_thresh_dist = 10    # Minimum distance threshold for emergency backward movement
#     ```

# %%
ultrasonic = Ultrasonic()
Motor = RobotController()
Speed = 40
rotation_speed = 30
threshold = 20
min_thresh_dist = 10

# %% [markdown]
# ### 3. The Obstacle Avoidance Function `obstacle_Avoid(left, front, right)`
#
# This function processes ultrasonic sensor data and determines robot movement direction for intelligent obstacle avoidance.
#
# - **Function Name**: `obstacle_Avoid`
#
# - **Parameters**:
#   - `left` *(float)*: Distance reading from left ultrasonic sensor in centimeters
#   - `front` *(float)*: Distance reading from front ultrasonic sensor in centimeters
#   - `right` *(float)*: Distance reading from right ultrasonic sensor in centimeters
#
# - **Usage**:
#   - **Primary obstacle detection** - Front sensor below threshold triggers avoidance:
#     ```python
#     if front < threshold:
#         if front <= min_thresh_dist:
#             print("Motion: Backward")
#             Motor.Backward(Speed)
#     ```
#   - **Emergency reverse** - Both sides blocked with front obstacle:
#     ```python
#     elif left < min_thresh_dist and right < min_thresh_dist:
#         print("Motion: Backward")
#         Motor.Backward(Speed)
#     ```
#   - **Directional avoidance** - Turn away from side obstacles when front blocked:
#     ```python
#     elif left < threshold:
#         print("Motion: Rotate Right")
#         Motor.move(speed=0, turn=rotation_speed)
#     elif right < threshold:
#         print("Motion: Rotate Left")
#         Motor.move(speed=0, turn=-rotation_speed)
#     ```
#   - **Side obstacle correction** - Maintain center path when side obstacles detected:
#     ```python
#     elif left < threshold:
#         print("Motion: Rotate Right")
#         Motor.move(speed=0, turn=rotation_speed)
#     elif right < threshold:
#         print("Motion: Rotate Left")
#         Motor.move(speed=0, turn=-rotation_speed)
#     ```
#   - **Clear path forward** - Proceed when no obstacles detected:
#     ```python
#     elif right > threshold and left > threshold and front > threshold:
#         print("Motion: Forward")
#         Motor.Forward(Speed)
#     ```
#   - **Default safety brake** - Stop for unknown conditions:
#     ```python
#     else:
#         print("Motion: Brake")
#         Motor.Brake()
#     ```

# %%
def obstacle_Avoid(left, front, right):
    
    if front < threshold:
        if front <= min_thresh_dist:
            print("Motion: Backward")
            Motor.Backward(Speed)
            time.sleep(0.1)
            # Motor.Brake()
        elif left < min_thresh_dist and right < min_thresh_dist:
            print("Motion: Backward")
            Motor.Backward(Speed)
            time.sleep(0.1)
            # Motor.Brake()
        elif left < threshold:
            print("Motion: Rotate Right")
            Motor.move(speed=0, turn=rotation_speed)
            time.sleep(0.5)
            # Motor.Brake()
        elif right < threshold:
            print("Motion: Rotate Left")
            Motor.move(speed=0, turn=-rotation_speed)
            time.sleep(0.5)
            # Motor.Brake()
        else:
            print("Motion: Backward")
            Motor.Backward(Speed)
            time.sleep(0.1)
            # Motor.Brake()
    
    elif left < threshold:
        print("Motion: Rotate Right")
        Motor.move(speed=0, turn=rotation_speed)
        time.sleep(1)
        # Motor.Brake()
    
    elif right < threshold:
        print("Motion: Rotate Left")
        Motor.move(speed=0, turn=-rotation_speed)  
        time.sleep(1)
        # Motor.Brake()
    
    elif right > threshold and left > threshold and front > threshold :
            print("Motion: Forward")
            Motor.Forward(Speed)
            time.sleep(0.1)
            # Motor.Brake()
    else:
        print("Motion: Brake")
        print("Unknown Condition Found ")
        Motor.Brake()

# %% [markdown]
# ### 4. The Main Control Function `main()`
#
# This function orchestrates the main program loop, coordinating sensor readings and obstacle avoidance decisions.
#
# - **Function Name**: `main`
#
# - **Usage**:
#   - **Continuous operation loop** - Main control loop using infinite while:
#     ```python
#     while True:
#     ```
#   - **Get sensor readings** - Obtain distance readings from all three ultrasonic sensors:
#     ```python
#     left, front, right = ultrasonic.distances()
#     time.sleep(0.1)
#     ```
#   - **Validate sensor data** - Check if all sensor readings are valid:
#     ```python
#     if left is not None and front is not None and right is not None:
#     ```
#   - **Display sensor values** - Output current distance readings for monitoring:
#     ```python
#     print("Left: {:.2f}".format(left))
#     print("Front: {:.2f}".format(front))
#     print("Right: {:.2f}".format(right))
#     ```
#   - **Execute obstacle avoidance** - Call avoidance function with sensor data:
#     ```python
#     obstacle_Avoid(left, front, right)
#     time.sleep(0.1)
#     ```
#   - **Handle invalid sensor data** - Safety brake when no valid sensor readings:
#     ```python
#     else:
#         print("No data received")
#         Motor.Brake()
#         time.sleep(1)
#     ```

# %%
def main():  
    while True: 
        # enc.encoder()
        left, front, right = ultrasonic.distances()
        time.sleep(0.1)
        if left is not None and front is not None and right is not None: 
            print("Left: {:.2f}".format(left)) 
            print("Front: {:.2f}".format(front))
            print("Right: {:.2f}".format(right)) 
            print(" ")
            obstacle_Avoid(left, front, right)
            time.sleep(0.1)
        else:
            print("No data received")
            Motor.Brake()
            time.sleep(1)

# %% [markdown]
# ### 5. Program Execution and Cleanup Workflow
#
# This workflow handles program startup, execution, and graceful shutdown with proper resource cleanup.
#
# - **Workflow Name**: Program Execution and Error Handling
#
# - **Usage**:
#   - **Main program execution** - Start the main control function:
#     ```python
#     try:
#         if __name__ == "__main__":
#             main()
#     ```
#   - **Keyboard interrupt handling** - Graceful shutdown on Ctrl+C:
#     ```python
#     except KeyboardInterrupt:
#         Motor.Brake()
#         print("Program Terminated")
#     ```
#   - **Final cleanup** - Ensure all resources are properly released:
#     ```python
#     finally:
#         Motor.cleanup()
#         print("Program Terminated")
#     ```

# %%
try:
    if __name__ == "__main__":
        main()

except KeyboardInterrupt:
    Motor.Brake()
    # enc.stop()
    print("Program Terminated")
finally:
    # enc.stop()
    Motor.cleanup()
    print("Program Terminated")
