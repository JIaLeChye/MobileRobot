# %% [markdown]
# # Object Tracking using KCF Tracker
#
# **Full Coding available at [object_tracking.py](object_tracking.py)**
#
# ## Description
# This script implements **object tracking** on a Raspberry Pi using the **OpenCV KCF Tracker**.
# It captures live video from the Raspberry Pi camera, initializes the tracker with a user-selected region of interest (ROI), and continuously updates the tracking box around the moving object.
# The system integrates motor and encoder libraries for robotic control, enabling the robot to respond dynamically to the tracked object.
#
# ## 1. Libraries Used
# - **Motor_Encoder** → For motor encoder integration and wheel feedback
# - **PCA9685_MC** → For PWM control of servos and motors
# - **OpenCV (cv2)** → For KCF tracking, image processing, and display
# - **Picamera2** → For capturing frames from the Raspberry Pi camera
# - **libcamera** → For camera configuration and controls
# - **NumPy** → For array manipulation and numerical operations

# %% [markdown]
# ## Installing Libraries & Dependencies
#
# ### Built-in Libraries
# These libraries are pre-installed with Raspberry Pi OS or come with the hardware support packages:
# - **Picamera2** → Camera interface for Raspberry Pi
# - **libcamera** → Camera control and configuration
# - **PCA9685_MC** → Motor controller library for servo and motor PWM control
# - **Motor Encoder** → Encoder handling library for wheel feedback
#
# ### User-Installed Libraries
# The following libraries must be installed manually:
# - **OpenCV** → Computer vision and image processing
# - **NumPy** → Array and matrix operations
#
# ### Installation Steps
#
# 1. **Install OpenCV**
#    - Follow the official guide at [OpenCV.org](https://docs.opencv.org/4.x/d2/de6/tutorial_py_setup_in_ubuntu.html)
#
# 2. **Install NumPy**
#    - Follow the instructions at [NumPy.org](https://numpy.org/install/)
#
#
# ### Verification of Installation
#
# 1. **Verify OpenCV**
#    - Open a Python file and type:
#      ```python
#      import cv2
#      print(cv2.__version__)
#      ```
#    - This will print the version of the OpenCV library installed.
#
# 2. **Verify NumPy**
#    - Open a Python file and type:
#      ```python
#      import numpy as np
#      ```
#    - If the code runs without errors, NumPy is successfully installed.

# %% [markdown]
# ## Let's Start Coding !
#
# ### 1. Import the Required Libraries
#
# This step imports all the necessary libraries for the **Object Tracking using KCF Tracker** script.
#
# - **OpenCV (`cv2`)** → Provides computer vision functions, including object detection and tracking.
# - **NumPy (`np`)** → Handles numerical computations and array operations for image processing.
# - **RPi_Robot_Hat_Lib (`RobotController`)** → Custom library to control robot motors and sensors.
# - **Picamera2 (`Picamera2`)** → Interfaces with the Raspberry Pi camera for frame capture.
# - **libcamera (`controls`, `Transform`)** → Provides advanced camera configuration and control.
# - **time** → Python built-in library used for delays and timing operations.

# %%
import cv2
import numpy as np
from RPi_Robot_Hat_Lib import RobotController
from picamera2 import Picamera2
from libcamera import controls, Transform 
import time

# %% [markdown]
# ### 2. The Initialization Block
#
# This initializes the **KCF tracker**, **camera**, and the **RPi_Robot_Hat_Lib** for the object tracking system.
#
#
# - **Global Variables**:
#   - `tracker`: OpenCV KCF tracker instance
#   - `frame_width`: Width of the camera frame (set to 640)
#   - `frame_height`: Height of the camera frame (set to 480)
#   - `cap`: Picamera2 object for capturing frames
#   - `Motor`: The `RPi_Robot_Hat_Lib` instance for controlling the robot
#   - `vertical`: Servo channel for vertical pan-tilt control
#   - `horizontal`: Servo channel for horizontal pan-tilt control
#
# - **Usage**:
#   - Create a **KCF Tracker** instance:
#     ```python
#     tracker = cv2.TrackerKCF_create()
#     ```
#   - Define **frame resolution** for camera preview:
#     ```python
#     frame_width = 640
#     frame_height = 480
#     ```
#   - Initialize and configure the **Picamera2** with vertical flip and continuous autofocus:
#     ```python
#     cap = Picamera2()
#     cap.configure(cap.create_preview_configuration(
#         main={"format": 'RGB888', "size": (640, 480)},
#         transform=Transform(vflip=1)))
#     cap.set_controls({"AfMode": controls.AfModeEnum.Continuous})
#     cap.start()
#     ```
#   - Initialize the **RPi_Robot_Hat_Lib** and set **servo positions** for pan-tilt alignment:
#     ```python
#     Motor = RobotController()
#     vertical = 2
#     horizontal = 1
#     Motor.set_servo(vertical, 180)
#     Motor.set_servo(horizontal, 90)
#     ```
#   - Add a short delay to stabilize camera and servo before starting tracking:
#     ```python
#     time.sleep(1)
#     ```

# %%
tracker = cv2.TrackerKCF_create() 
frame_width = 640  
frame_height = 480
cap = Picamera2()
cap.configure(cap.create_preview_configuration(main={"format": 'RGB888', "size": (640, 480)},transform=Transform(vflip=1)))
cap.set_controls({"AfMode": controls.AfModeEnum.Continuous})
cap.start()

Motor = RobotController()
# enc = Encoder()

vertical = 2
horizontal = 1
Motor.set_servo(vertical, 180)
Motor.set_servo(horizontal, 90)
# All process should be start after the servo @ camera position is set !
time.sleep(1)

# %% [markdown]
# ### 3. The Function `tracking(frame, x, y, w, h)`
#
# This function handles **object tracking visualization** and **motor movement control** based on the bounding box detected by the KCF tracker.
#
# - **Function Name**: `tracking`
#
# - **Parameters**:
#   - `frame (numpy.ndarray)` → The current video frame from the camera.
#   - `x (int)` → Top-left X coordinate of the bounding box.
#   - `y (int)` → Top-left Y coordinate of the bounding box.
#   - `w (int)` → Width of the bounding box.
#   - `h (int)` → Height of the bounding box.
#
# - **Global Variables**:
#   - `Motor`: Instance of `RPi_Robot_Hat_Lib` used for controlling motors.
#
# - **Usage**:
#   - Draw a **bounding box** around the tracked object and overlay information text:
#     ```python
#     cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
#     cv2.putText(frame, "Tracking", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
#     cv2.putText(frame, "Press 'q' to quit", (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
#     cv2.putText(frame, f"X:{x} , Y:{y}", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
#     ```
#
#   - Calculate the **center point** of the bounding box and mark it with a red circle:
#     ```python
#     center_x = x + w // 2
#     center_y = y + h // 2
#     cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)
#     ```
#
#   - Implement **tracking logic** based on object position:
#     - If the object is near the **upper region (100–220px Y range)** → move faster.
#       ```python
#       if center_y < 220 and center_y > 100:
#           if center_x < 300:
#               print("Turn Left")
#               Motor.move(speed=0, turn=-20)
#           if center_x > 340:
#               print("Turn Right")
#               Motor.move(speed=0, turn=20)
#           else:
#               Motor.Forward(20)
#       ```
#     - If the object is in the **closer region (240–440px Y range)** → approach slowly.
#       ```python
#       elif center_y > 240 and center_y < 440:
#           if center_x < 300:
#               print("Turn Left")
#               Motor.move(speed=0, turn=-10)
#           if center_x > 340:
#               print("Turn Right")
#               Motor.move(speed=0, turn=10)
#           else:
#               Motor.Forward(10)
#       ```
#     - If the object is out of range → stop the robot.
#       ```python
#       else:
#           Motor.Brake()
#       ```

# %%
def tracking(frame, x,y,w,h):
    
    cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
    cv2.putText(frame, "Tracking", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    cv2.putText(frame, "Press 'q' to quit", (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    cv2.putText(frame, f"X:{x} , Y: {y}", (x ,y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    # Calculate the center of Bounding Box 
    center_x = x + w // 2
    center_y = y + h // 2
    cv2.circle(frame, (center_x, center_y), 5, (0, 0, 255), -1)  # Draw a circle at the center
    # Tracking Logic 
    # enc.encoder() 
    if center_y < 220 and center_y > 100:
        if center_x < 300:
            print("Turn Left")
            Motor.move(speed=0, turn=-20) 
        if center_x > 340:
            print("Turn Right")
            Motor.move(speed=0, turn= 20)
        else:
            Motor.Forward(20)
    # Slow Approch        
    elif center_y > 240 and center_y < 440:
        if center_x < 300:
            print("Turn Left")
            Motor.move(speed=0, turn=-10)
        if center_x > 340:
            print("Turn Right")
            Motor.move(speed=0, turn=10)
        else:
            Motor.Forward(10)
    else:
        Motor.Brake()

# %% [markdown]
# ### 4. The Function `main()`
#
# This function runs the **object tracking loop** using the KCF tracker, continuously updating the tracked bounding box and controlling robot movements.
#
# - **Function Name**: `main`
#
# - **Global Variables**:
#   - `cap`: `Picamera2` object used to capture frames.
#   - `tracker`: OpenCV KCF tracker instance.
#   - `Motor`: The `RPi_Robot_Hat_Lib` object for robot motor control.
#
# - **Usage**:
#   - Capture an initial frame and select an **ROI (Region of Interest)** for tracking:
#     ```python
#     frame = cap.capture_array()
#     bbox = cv2.selectROI(frame, showCrosshair=True, fromCenter=False)
#     cv2.destroyWindow("ROI selector")
#     ```
#   - Initialize the **KCF tracker** with the first frame and ROI:
#     ```python
#     tracker.init(frame, bbox)
#     ```
#   - Enter a continuous loop to capture frames and update the tracker:
#     ```python
#     while True:
#         frame = cap.capture_array()
#         frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
#         success, box = tracker.update(frame)
#     ```
#   - If tracking is successful, update bounding box and call `tracking()` for movement decisions:
#     ```python
#     if success:
#         (x, y, w, h) = [int(v) for v in box]
#         tracking(frame, x, y, w, h)
#     ```
#   - If tracking fails, display a **failure message** and stop the robot:
#     ```python
#     else:
#         cv2.putText(frame, "Tracking failure", (20, 40),
#                     cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
#         Motor.Brake()
#     ```
#   - Display the tracking output in a window:
#     ```python
#     cv2.imshow('Tracking_Area', frame)
#     ```
#   - Allow user to **exit loop by pressing `'q'`**:
#     ```python
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break
#     ```

# %%
ef main(): 
    frame = cap.capture_array()
    bbox = cv2.selectROI(frame, showCrosshair=True, fromCenter=False)
    cv2.destroyWindow("ROI selector")
 
    # Initialize tracker with first frame and bounding box
    tracker.init(frame, bbox)

    # if not cap.isOpened():
    #     print("Error: Could not open video capture.")
    #     return
    # print(f"Tracking started with ROI: {bbox}")
    
    while True:
        frame = cap.capture_array()  # Read frame
        # Convert the frame from RGBA to BGR (From 4 channel to 1 channel)
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2BGR)
        # Tracking mode: update the tracker and draw the tracked bounding box
        success, box = tracker.update(frame)  # Update the tracker with the new frame

        if success:
            (x, y, w, h) = [int(v) for v in box]
            tracking(frame, x,y,w,h)
        else:
            cv2.putText(frame, "Tracking failure", (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
            Motor.Brake() 
        cv2.imshow('Tracking_Area', frame)
        
        # Press 'q' to quit
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

      # Release the video capture when done

# %% [markdown]
# ### 5. The Termination Block
#
# This block handles **program execution**, including proper termination on **normal exit** or **KeyboardInterrupt**. It ensures that motors, camera, and OpenCV resources are safely released.
#
# - **Execution Guard**:
#   - Runs the program only when the script is executed directly:
#     ```python
#     if __name__ == '__main__':
#         main()
#     ```
#
# - **Exception Handling**:
#   - Catches `KeyboardInterrupt` (Ctrl + C) to stop execution gracefully:
#     ```python
#     except KeyboardInterrupt:
#         print("KeyboardInterrupt")
#     ```
#
# - **Cleanup Actions**:
#   - Release robot motors and perform GPIO cleanup:
#     ```python
#     Motor.cleanup()
#     # enc.stop()   # Optional: stop encoder if used
#     ```
#   - Stop the Picamera2 stream:
#     ```python
#     cap.stop()
#     ```
#   - Close all OpenCV display windows:
#     ```python
#     cv2.destroyAllWindows()
#     ```
#   - Print termination message for clarity:
#     ```python
#     print("Program Terminated \nExiting....")
#     ```

# %%
try:
    if __name__ == '__main__':
        main()
except KeyboardInterrupt:
    print("KeyboardInterrupt")
    
finally:
    Motor.cleanup()
    # enc.stop()
    cap.stop()
    cv2.destroyAllWindows()
    print("Program Terminated \nExiting....")
