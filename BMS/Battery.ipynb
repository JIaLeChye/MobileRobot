# %% [markdown]
# # Battery Management System (BMS)
# **Full Coding available at [Battery.py](Battery.py)**
# <br>
# This is the documentation for the Battery Management System that monitors robot battery levels and provides safety features.
#
# The BMS continuously monitors battery voltage, displays status on an OLED screen, provides low battery warnings, and automatically shuts down the system when battery levels become critically low to prevent damage. This system can also run as a background service.
#
# ***Libraries Used In The Script***
# - time - For timing and delays
# - os - For system operations and shutdown commands
# - sys - For system-specific parameters and functions
# - logging, logging.handlers - For comprehensive logging and file management
# - busio, board - For I2C communication with OLED display
# - signal - For handling system signals (SIGTERM)
# - adafruit_ssd1306 - For OLED display control
# - PIL (Pillow) - For image processing and text rendering on OLED
# - RPi_Robot_Hat_Lib - Custom robot control library with battery monitoring

# %% [markdown]
# ## Installing Libraries & Dependencies
#
# ### Built-in Libraries:
# - time, os, sys, signal (Built-in Python libraries)
#
# ### External Libraries Required:
# 1. **Adafruit CircuitPython Libraries**:
#    - `pip install adafruit-circuitpython-ssd1306`
#    - `pip install adafruit-blinka`
#
# 2. **PIL (Pillow)**:
#    - `pip install Pillow`
#
# 3. **Board Libraries**:
#    - `pip install board busio`
#
# 4. **Custom Library**:
#    - RPi_Robot_Hat_Lib (Hardware-specific library)
#
# ## Let's Start Coding !
# ### 1. Import Required Libraries
# Import all necessary libraries for battery monitoring, display control, and system management:

# %%
from RPi_Robot_Hat_Lib import RobotController
import time 
import os
import sys
import logging, logging.handlers
import busio 
import board
import signal 
import adafruit_ssd1306 
from PIL import Image, ImageDraw, ImageFont

# %% [markdown]
# ### 2. Logger Setup and Global Configuration
# Configure comprehensive logging system for debugging and monitoring the BMS operation.
#
# #### Logging Configuration:
# - **Logger Name**: 'battery_logger' for easy identification
# - **Log Level**: DEBUG (captures all levels of information)
# - **Format**: Timestamp - Level - Function - Message for detailed tracking
#
# #### Multiple Output Handlers:
# - **stderr_handler**: Error messages (WARNING level and above)
# - **stdout_handler**: Debug and info messages
# - **Custom formatting**: Provides detailed context for each log entry

# %%
# Logger Setup
logger = logging.getLogger('battery_logger')
logger.setLevel(logging.DEBUG)

# Create a log format with timestamp, level name, function name, and message
formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(funcName)s - %(message)s')


# Create a stderr handler for error logs (critical and above)
stderr_handler = logging.StreamHandler(sys.stderr)
stderr_handler.setLevel(logging.WARNING)
stderr_handler.setFormatter(formatter)

# Create a stdout handler for debug and info logs
stdout_handler = logging.StreamHandler(sys.stdout)
stdout_handler.setLevel(logging.DEBUG)
stdout_handler.setFormatter(formatter)

# Add handlers to the logger
# logger.addHandler(log_handler)
logger.addHandler(stderr_handler)
logger.addHandler(stdout_handler)

# %% [markdown]
# ### 3. Clear the History Content in Log Files
#
# The `clear_log_files()` function ensures that old log content is removed before new logging begins. This helps maintain clean and up-to-date log files for battery monitoring.
#
# - **Function Name**: `clear_log_files()`
#
# - **Usage**:
#     1. Define the log file paths:
#     ```python
#         log_dir = os.environ.get('BATTERY_LOG_DIR')
#     ```
#
#     2. Rise error if log paths is not found :
#     ```python
#         if not log_dir:
#             logger.error("BATTERY_LOG_DIR environment variable not set.")
#             raise RuntimeError("BATTERY_LOG_DIR environment variable not set.")
#     ```
#
#     3. Clear the log history in the files:
#     ```python
#         cleared = 0
#          stdout_log = os.path.join(log_dir, "battery_log.txt")
#         cleared = 0
#         try:
#             open(stdout_log, 'w').close()
#             cleared += 1
#         except Exception as e:
#             logger.warning(f"Could not truncate log file {stdout_log}: {e}")
#
#         if cleared:
#             logger.info(f"Cleared {cleared} log file(s) in {log_dir}")
#     except Exception as e:
#         logger.warning(f"Log cleanup exception: {e}")
#     ```

# %%
def clear_log_files():
    """Truncate system log file (battery_log.txt) at startup.
    Log path is determined by the BATTERY_LOG_DIR environment variable.
    """
    try:
        log_dir = os.environ.get('BATTERY_LOG_DIR')
        if not log_dir:
            logger.error("BATTERY_LOG_DIR environment variable not set.")
            raise RuntimeError("BATTERY_LOG_DIR environment variable not set.")

        stdout_log = os.path.join(log_dir, "battery_log.txt")
        cleared = 0
        try:
            open(stdout_log, 'w').close()
            cleared += 1
        except Exception as e:
            logger.warning(f"Could not truncate log file {stdout_log}: {e}")

        if cleared:
            logger.info(f"Cleared {cleared} log file(s) in {log_dir}")
    except Exception as e:
        logger.warning(f"Log cleanup exception: {e}")

# %% [markdown]
# ### 4. Define Global Variables and Initialize Libraries
#
# Define the global variables used in the script and initialize the required libraries.
#
# - **Global Variables**
#   - `LOW_BATTERY_THRESH` – Voltage threshold at which the battery is considered low.
#   - `SHUTDOWN_VOLTAGE` - The minimum voltage threshold to shutdown the robot
#   - `USB_VOLTAGE` – Voltage value when the robot is powered by USB Type-C.
#   - `CHECK_INTERVAL` – Time interval (in seconds) at which the script performs a voltage check.
#
#
# - **Library Initialization**
#   - `RobotController()` is initialized and the instance is stored in the variable `robot`.
#     ```python
#     robot = RobotController()
#     ```
#   - Initialize the **I2C** bus using the predefined **SDA** and **SCL** pins from the **board** library.
#     ```python
#     i2c = busio.I2C(board.SCL, board.SDA)
#     ```
#   - Initialize the `adafruit_ssd1306` OLED driver with a resolution of **128×64**, using the I2C bus.
#     ```python
#     disp = adafruit_ssd1306.SSD1306_I2C(128, 64, i2c)
#     ```
#   - Clear the OLED display by filling the screen with zeros and then updating it with `show()`.
#     ```python
#     disp.fill(0)
#     disp.show()
#     ```
#   - Create a new monochrome image buffer matching the OLED display size, initialize a drawing context, and load the default font for text rendering.
#     ```python
#     image = Image.new("1", (disp.width, disp.height))
#     draw = ImageDraw.Draw(image)
#     font = ImageFont.load_default()
#     ```

# %%
robot = RobotController()
LOW_BATTERY_TRESH = 11
SHUTDOWN_VOLTAGE = 10.5
USB_VOLTAGE = 5
CHECK_INTERVAL = 30

i2c = busio.I2C(board.SCL, board.SDA)
disp = adafruit_ssd1306.SSD1306_I2C(128, 64, i2c)
disp.fill(0)
disp.show()
image = Image.new("1", (disp.width, disp.height))
draw = ImageDraw.Draw(image)
font = ImageFont.load_default()

# %% [markdown]
# ### 5. Display Battery Status
#
# The `Display_battery()` function displays the battery status on the OLED screen and logs the information into the log file.
#
# - **Function Name**: `Display_battery()`
#
# - **Usage**:
#
#     - Obtain the battery value:
#     ```python
#     def Display_battery(battery_stat):
#         voltage = battery_stat
#     ```
#
#     - Log the battery status into the log file with a specific format:
#       > `YYYY-MM-DD HH:MM:SS --> Battery Voltage: XX.XV`
#     ```python
#     CurrentTime = time.time()
#     CurrentTime = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(CurrentTime))
#     logger.info(f"{CurrentTime} --> Battery Voltage: {voltage:.1f}V")
#     ```
#
#     - Update the OLED to display the battery status:
#       - Create an empty canvas for the battery status UI (User Interface).
#       ```python
#       if all([disp, image, draw, font]):
#           draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=0)
#       ```
#
#     - Display the battery voltage level:
#     ```python
#           draw.text((0, 0), "Battery Status:", font=font, fill=255)
#           draw.text((0, 20), f"Voltage: {voltage:.1f}V", font=font, fill=255)
#     ```
#
#     - Map the voltage value to the progress bar to visualize the battery level:
#     ```python
#           # Add battery level indicator (11V–13V range)
#           level = min(100, max(0, (voltage - 11) * 100 / (13.0 - 11)))
#           draw.text((0, 40), f"Level: {level:.0f}%", font=font, fill=255)
#
#           # Draw battery bar
#           bar_width = int(disp.width * level / 100)
#           draw.rectangle((0, 55, bar_width, 63), outline=255, fill=255)
#           disp.image(image)
#           disp.show()
#     ```
#
#     - Error handling if the OLED is not accessible:
#     ```python
#       else:
#           logger.error("OLED display not initialized.")
#       time.sleep(1)
#     ```
#
#     - Example Display:
#         ```UI
#         +--------------------------+
#         | Battery Status:          |
#         | Voltage: 12.1V           |
#         | Level: 60%               |
#         | [██████████------]       |
#         +--------------------------+
#         ````

# %%
def Display_battery(battery_stat):
    voltage = battery_stat
    CurrentTime = time.time() 
    CurrentTime = time.strftime("%Y-%m-%d %H:%M:%S", time.localtime(CurrentTime))
    logger.info(f"{CurrentTime} --> Battery Voltage: {voltage:.1f}V")
    
    # Update OLED display
    if all([disp, image, draw, font]):
        draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=0)
        draw.text((0, 0), "Battery Status:", font=font, fill=255)
        draw.text((0, 20), f"Voltage: {voltage:.1f}V", font=font, fill=255)
        
        # Add battery level indicator (9V-13V range)
        level = min(100, max(0, (voltage - 11) * 100 / (13.0 - 11)))  # Map 9V-13V to 0-100%
        draw.text((0, 40), f"Level: {level:.0f}%", font=font, fill=255)
        
        # Draw battery bar
        bar_width = int(disp.width * level / 100)
        draw.rectangle((0, 55, bar_width, 63), outline=255, fill=255)
        disp.image(image)
        disp.show()
    else:
        logger.error("OLED display not initialized.")   
    time.sleep(1)

# %% [markdown]
# ### 6. Handle System Signals
# This step ensures the script exits cleanly when terminated by external systems like **systemd**.
#
# - **Function Name**: `handle_sigterm(signum, frame)`
# - **Usage**:
#   - Exit the Python script when a stop signal is received from `systemctl`.
#     <br> *When `sys.exit(0)` is called, Python will also execute the `finally` block in the script (if present).*
#     ```python
#     def handle_sigterm(signum, frame):
#         sys.exit(0)
#     ```
#   - Register the handler to catch the `SIGTERM` signal sent by `systemctl`.
#     ```python
#     signal.signal(signal.SIGTERM, handle_sigterm)
#     ```

# %%
# Graceful shutdown handler for systemd service
def handle_sigterm(signum, frame):
    sys.exit(0)

signal.signal(signal.SIGTERM, handle_sigterm)

# %% [markdown]
# ### 7. Battery Checker
# The `battery_checker` function monitors the robot’s battery status, updates the OLED screen with warnings, and initiates a shutdown if voltage is critically low.
#
# - **Function Name**: `battery_checker(battery_stat)`
# - **Usage**:
#
#   - **Low Battery Warning**
#     - If battery voltage is **below `LOW_BATTERY_TRESH` but above `USE_VOLTAGE`**, log a warning and display an OLED alert.
#     - Flash the display with inverted text and play buzzer tones to attract attention.
#     ```python
#         if USB_VOLTAGE < battery_stat <= LOW_BATTERY_TRESH:
#             logger.warning(f"Battery Low Voltage detected: {battery_stat}")
#             disp.fill(0)
#             disp.show()
#             # Clear the image buffer to avoid overlapping text
#             draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=0)
#             draw.text((0, 10), "LOW BATTERY!", font=font, fill=255)
#             draw.text((0, 20), "ROBOT WILL SHUTDOWN", font=font, fill=255)
#             draw.text((0, 30), "AT 10.5V", font=font, fill=255)
#             disp.image(image)
#             disp.show()
#             time.sleep(5)
#             for i in range(5):
#                 robot.play_tone(2000, 1)
#                 disp.fill(0)
#                 disp.show()
#                 time.sleep(0.2)
#                 # Clear the image buffer before drawing the next frame
#                 # Invert visuals for attention
#                 draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=255)
#                 draw.text((30, 30), "LOW BATTERY!", font=font, fill=0)
#                 disp.image(image)
#                 disp.show()
#                 # time.sleep(1)
#             robot.cleanup_buzzer()
#     ```
#
#   - **Critical Battery Shutdown**
#     - If battery voltage drops to **10.5V or lower**, log repeated warnings and show a shutdown alert on the OLED.
#     - Execute a system shutdown command for safety.
#     ```python
#       if USB_VOLTAGE < battery_stat <= SHUTDOWN_VOLTAGE:
#         for i in range(5):
#           logger.warning(f"Shutting down due to low battery: {battery_stat}")
#           disp.fill(0)
#           disp.show()
#           # Clear the image buffer before drawing the next frame
#           # Invert visuals for attention
#           draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=255)
#           # Split into two lines to avoid any missing-space rendering issues
#           draw.text((10, 20), "PLEASE", font=font, fill=0)
#           draw.text((10, 35), "RECHARGE!", font=font, fill=0)
#           draw.text((10, 50), f"VOLTAGE: {battery_stat}V", font=font, fill=0)
#           disp.image(image)
#           disp.show()
#           time.sleep(10)
#           # Use passwordless sudo with absolute path for reliability under systemd
#         os.system("sudo -n /usr/sbin/shutdown -h now")
#     ```
#
#   - **USB Power Warning**
#     - If voltage equals or falls below **USB_VOLTAGE**, log a USB power warning and update the OLED to advise against starting the motors.
#     ```python
#       elif battery_stat <= USB_VOLTAGE:
#         logger.warning(f"USB Voltage detected: {battery_stat}")
#         # Clear the image buffer before drawing USB warning
#         draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=0)
#         draw.text((0, 10), "USB Voltage detected", font=font, fill=255)
#         draw.text((0, 20), f"VOLTAGE: {battery_stat}", font=font, fill=255)
#         draw.text((0, 30), "CAUTION!", font=font, fill=255)
#         draw.text((0, 40), "DO NOT START ", font=font, fill=255)
#         draw.text((0, 50), "MOTOR!", font=font, fill=255)
#         disp.image(image)
#         disp.show()
#     ```
#
#   - **Normal Operation**
#     - If voltage is within a safe range, display the battery status using the `Display_battery()` function.
#     ```python
#       else:
#           Display_battery(battery_stat)
#     ```

# %%
def battery_checker(battery_stat):
        if USB_VOLTAGE < battery_stat <= LOW_BATTERY_TRESH:
            logger.warning(f"Battery Low Voltage detected: {battery_stat}")
            disp.fill(0)
            disp.show()
            # Clear the image buffer to avoid overlapping text
            draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=0)
            draw.text((0, 10), "LOW BATTERY!", font=font, fill=255)
            draw.text((0, 20), "ROBOT WILL SHUTDOWN", font=font, fill=255)
            draw.text((0, 30), "AT 10.5V", font=font, fill=255)
            disp.image(image)
            disp.show()
            time.sleep(5)
            for i in range(5):
                robot.play_tone(2000, 1)
                disp.fill(0)
                disp.show()
                time.sleep(0.2)
                # Clear the image buffer before drawing the next frame
                # Invert visuals for attention
                draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=255)
                draw.text((30, 30), "LOW BATTERY!", font=font, fill=0)
                disp.image(image)
                disp.show()
                # time.sleep(1)
            robot.cleanup_buzzer()
            # time.sleep(CHECK_INTERVAL)
            if USB_VOLTAGE < battery_stat <= SHUTDOWN_VOLTAGE: 
                for i in range(5): 
                    logger.warning(f"Shutting down due to low battery: {battery_stat}")
                    disp.fill(0)
                    disp.show()
                    # Clear the image buffer before drawing the next frame
                    # Invert visuals for attention
                    draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=255)
                    # Split into two lines to avoid any missing-space rendering issues
                    draw.text((10, 20), "PLEASE", font=font, fill=0)
                    draw.text((10, 35), "RECHARGE!", font=font, fill=0)
                    draw.text((10, 50), f"VOLTAGE: {battery_stat}V", font=font, fill=0)
                    disp.image(image)
                    disp.show()
                    time.sleep(10)
                # Use passwordless sudo with absolute path for reliability under systemd
                os.system("sudo -n /usr/sbin/shutdown -h now")
        elif battery_stat <= USB_VOLTAGE:
            logger.warning(f"USB Voltage detected: {battery_stat}")
            # Clear the image buffer before drawing USB warning
            draw.rectangle((0, 0, disp.width, disp.height), outline=0, fill=0)
            draw.text((0, 10), "USB Voltage detected", font=font, fill=255)
            draw.text((0, 20), f"VOLTAGE: {battery_stat}", font=font, fill=255)
            draw.text((0, 30), "CAUTION!", font=font, fill=255)
            draw.text((0, 40), "DO NOT START ", font=font, fill=255)
            draw.text((0, 50), "MOTOR!", font=font, fill=255)
            disp.image(image)
            disp.show()
        else:
            Display_battery(battery_stat)
            # time.sleep(1)

# %% [markdown]
# ### 8. Main Function
# The `main()` function serves as the entry point of the script. It initializes the system, plays a startup tone, and continuously monitors the battery status.
#
# - **Function Name**: `main()`
# - **Usage**:
#
#   - **Log Initialization**
#     - Clear existing log files and log the start of the script.
#     ```python
#         clear_log_files()
#         logger.debug("\n\n")
#         logger.debug("/--------------------------/")
#         logger.debug("-------Script Started-------")
#         logger.debug("/--------------------------/")
#     ```
#
#   - **Startup Signal**
#     - Play two short buzzer tones to indicate that the script has started successfully.
#     ```python
#         robot.play_tone(1000, 0.5)
#         time.sleep(0.2)
#         robot.play_tone(1000, 0.5)
#         robot.cleanup_buzzer()
#     ```
#
#   - **Battery Monitoring Loop**
#     - Continuously read the battery voltage.
#     - Pass the reading to the `battery_checker()` function for evaluation and display.
#     - Wait for the defined `CHECK_INTERVAL` before repeating.
#     ```python
#         while True:
#             try:
#                 battery_stat = robot.get_battery()
#                 battery_checker(battery_stat)
#                 time.sleep(CHECK_INTERVAL)
#             except Exception as e:
#                 logger.error(f"Failed to read battery or update display: {e}")
#
#     ```

# %%
def main():
    global font
    # Clear existing log files at startup
    clear_log_files()
    logger.debug("\n\n")
    logger.debug("/--------------------------/")
    logger.debug("-------Script Started-------")
    logger.debug("/--------------------------/")

    robot.play_tone(1000, 0.5)
    time.sleep(0.2)
    robot.play_tone(1000, 0.5)
    robot.cleanup_buzzer()
    while True: 
        try:
            battery_stat = robot.get_battery()  
            battery_checker(battery_stat)
            time.sleep(CHECK_INTERVAL)
        except Exception as e:
            logger.error(f"Failed to read battery or update display: {e}")

# %% [markdown]
# ### 9. Script Execution and Cleanup
# This section ensures the script starts execution correctly and exits cleanly when interrupted or an error occurs.
#
# - **Execution Block**
#   - Run the `main()` function when the script is executed directly.
#     ```python
#     if __name__ == '__main__':
#         main()
#     ```
#
# - **Exception Handling**
#   - **Keyboard Interrupt**
#     - When the script is run in a terminal and the user performs a terminate input ***(Ctrl + C)***, shut down the script with `robot.cleanup()` to clean the *`RobotController`* library.
#     ```python
#     except KeyboardInterrupt:
#         robot.cleanup()
#         disp.fill(0)
#         disp.show()
#         logger.warning("Program Exit: User Interrupt")
#     ```
#
#   - **Error Handling**
#     - Catch any runtime error message and log it.
#     ```python
#     except Exception as e:
#         logger.error(f"An error occurred: {e}")
#     ```
#
#   - **Final Cleanup**
#     - Clear the OLED screen and clean the `RobotController` library resources before exiting.
#     ```python
#     finally:
#         disp.fill(0)
#         disp.show()
#         logger.info("Script Ended")
#         robot.cleanup()
#         exit()
#     ```

# %%
try:
    if __name__ == '__main__':
        main() 
except KeyboardInterrupt:
    robot.cleanup()  
    disp.fill(0)
    disp.show() 
    logger.warning("Program Exit: User Interupt")
except Exception as e:
    logger.error(f"An error occurred: {e}")     
finally:
    disp.fill(0)
    disp.show() 
    logger.info("Script Ended")
    robot.cleanup() 
    exit()
