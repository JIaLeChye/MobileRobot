# %% [markdown]
# # Object Tracking with Obstacle Avoidance using OpenCV
# **Full Coding available at [Object_Tracking_and_Avoidance.py](Object_Tracking_and_Avoidance.py)**
# <br>
# This is the documentation for Object Tracking with Obstacle Avoidance using OpenCV, threading, and ultrasonic sensors.
#
# This advanced project combines computer vision object tracking with intelligent obstacle avoidance. The system uses color-based object detection to track targets while simultaneously monitoring for obstacles using ultrasonic sensors. The implementation uses multi-threading to handle camera capture, object tracking, and obstacle avoidance concurrently.
#
# ***Libraries Used In The Script***
# - OpenCV (cv2) - For image processing and computer vision
# - Numpy (np) - For numerical operations and array handling
# - Picamera2 - Raspberry Pi camera interface
# - libcamera - Camera control library
# - RPi_Robot_Hat_Lib - Custom robot control library
# - time - For timing operations
# - threading - For concurrent execution of multiple tasks
# - Ultrasonic_sens - Custom ultrasonic sensor library

# %% [markdown]
# ## Installing Libraries & Dependencies
# - Built-in Libraries:
#     - Picamera2 (Pre-installed on Raspberry Pi OS)
#     - libcamera (Pre-installed on Raspberry Pi OS)
#     - time (Built-in Python library)
#     - threading (Built-in Python library)
#     - Numpy (Usually pre-installed)
# - Libraries Requiring Installation:
#     - OpenCV
#     - RPi_Robot_Hat_Lib (Custom library)
#     - Ultrasonic_sens (Custom library)
#
# ## Installing Required Libraries
# 1. **OpenCV** [OpenCV.org](https://docs.opencv.org/4.x/d2/de6/tutorial_py_setup_in_ubuntu.html)
#     - In the terminal type: `pip install opencv-python`
#     - To verify installation, in a Python file type: <br>
#     `import cv2` <br>
#     `print(cv2.__version__)`
#     - This will print the version of OpenCV library installed
#
# 2. **Custom Libraries**
#     - RPi_Robot_Hat_Lib: Custom robot control library
#     - Ultrasonic_sens: Custom ultrasonic sensor library
#     - Install according to your robot hardware setup instructions
#
# ## Let's Start Coding !
# ### 1. Import all the required libraries
# - OpenCV (cv2) - For image processing and object tracking
# - Numpy (np) - For numerical operations
# - Picamera2 - For Raspberry Pi camera control
# - libcamera - For camera configuration
# - RPi_Robot_Hat_Lib - For robot motor and servo control
# - time - For timing operations
# - threading - For concurrent task execution
# - Ultrasonic_sens - For obstacle detection

# %%
import cv2
import time
import numpy as np
from picamera2 import Picamera2
from libcamera import controls, Transform 
from RPi_Robot_Hat_Lib import RobotController
from Ultrasonic_sens import Ultrasonic
import threading

# %% [markdown]
# ### 2. The Initialization Block
#
# This block initializes the **camera**, **motor controller**, **ultrasonic sensor**, and sets up **threading synchronization** for object tracking and obstacle avoidance.
#
# - **Global Variables**:
#   - `picam` → Picamera2 object for capturing frames
#   - `Motor` → Instance of `RPi_Robot_Hat_Lib.RobotController` for robot control
#   - `ultrasonic` → Instance of `Ultrasonic` for distance measurement
#   - `Frame_lock` → Threading lock to synchronize camera frame access
#   - `shutdown_event` → Event flag to signal shutdown across threads
#   - `Avoidance_event` → Event flag to trigger obstacle avoidance mode
#   - `latest_frame` → Stores the most recent camera frame for processing
#   - `Tracking_mode` → Boolean flag to indicate if tracking is active
#   - `Avoidance_mode` → Boolean flag to indicate if avoidance is active
#   - `vertical` / `horizontal` → Servo channel assignments for pan-tilt camera
#   - `MIN_AREA_THRESHOLD` → Minimum contour area for valid object detection
#   - `threshold` → Distance threshold for obstacle avoidance
#   - `min_thresh_dist` → Minimum distance threshold for emergency avoidance
#
# - **Usage**:
#   - **Camera Initialization**:
#     ```python
#     picam = Picamera2()
#     picam.configure(main={"format": 'RGB888', "size": (640, 480)}, transform=Transform(vflip=1))
#     picam.start()
#     picam.set_controls({"AfMode": controls.AfModeEnum.Continuous})
#     ```
#     Configures the Raspberry Pi camera with resolution **640x480**, applies vertical flip, and enables continuous autofocus.
#
#   - **Motor & Ultrasonic Initialization**:
#     ```python
#     Motor = RobotController()
#     ultrasonic = Ultrasonic()
#     ```
#     Initializes motor control library and ultrasonic sensor.
#
#   - **Threading Setup**:
#     ```python
#     Frame_lock = threading.Lock()
#     shutdown_event = threading.Event()
#     Avoidance_event = threading.Event()
#     ```
#     Provides synchronization for safe multi-threaded access and control flags for robot behavior.
#
#   - **Servo Initialization**:
#     ```python
#     vertical = 2
#     horizontal = 1
#     Motor.set_servo(vertical, 160)
#     Motor.set_servo(horizontal, 90)
#     ```
#     Positions the pan-tilt servos to default angles for the camera.
#
#   - **Threshold Setup**:
#     ```python
#     MIN_AREA_THRESHOLD = 3000
#     threshold = 30
#     min_thresh_dist = 10
#     ```
#     Defines detection and avoidance thresholds for object tracking and obstacle detection.
#
#   - **Completion Message**:
#     ```python
#     print("Initialasition Complete")
#     ```
#     Confirms that initialization is successful.

# %%
# Initialize camera, motor, encoder, and ultrasonic sensor
picam = Picamera2()
picam.configure(main={"format": 'RGB888', "size": (640, 480)},transform=Transform(vflip=1))
picam.start()
picam.set_controls({"AfMode": controls.AfModeEnum.Continuous})
Motor = RobotController()
ultrasonic = Ultrasonic()

# Threading synchronization
Frame_lock = threading.Lock()
shutdown_event = threading.Event() 
Avoidance_event = threading.Event() 

# Declare global variable 
latest_frame = None
Tracking_mode = False 
Avoidance_mode = False 


# Set initial servo position
vertical = 2
horizontal = 1
Motor.set_servo(vertical, 160)
Motor.set_servo(horizontal, 90)
# Thresholds
MIN_AREA_THRESHOLD = 3000 # Minimum area to detect color
threshold = 30 # Threshod for obstacle avoidance 
min_thresh_dist = 10 # Minimum threshoold for obstacle avoidance
print("Initialasition Complete")

# %% [markdown]
# ### 3. The Function `camera()`
#
# This function continuously captures frames from the **Picamera2** and stores them into the global variable `latest_frame` for use by other threads.
#
# - **Function Name**: `camera`
#
# - **Global Variables**:
#   - `latest_frame` → Stores the most recent frame captured from the camera
#   - `picam` → Picamera2 object for capturing frames
#   - `Frame_lock` → Threading lock for safe frame access
#   - `shutdown_event` → Threading event to stop the camera loop
#
# - **Usage**:
#   - Starts the **Picamera2** stream:
#     ```python
#     picam.start()
#     ```
#   - Continuously captures frames until `shutdown_event` is set:
#     ```python
#     while not shutdown_event.is_set():
#     ```
#   - Uses a **threading lock** to safely update the global frame buffer:
#     ```python
#     with Frame_lock:
#         latest_frame = picam.capture_array()
#     ```
#   - Adds a short delay to reduce CPU usage:
#     ```python
#     time.sleep(0.01)
#     ```
#   - Stops the camera once the shutdown event is triggered:
#     ```python
#     picam.stop()
#     ```

# %%
def camera():
    global latest_frame 
    picam.start() 
    while not shutdown_event.is_set():
        with Frame_lock:
            latest_frame = picam.capture_array()
        time.sleep(0.01) # Prevent high CPU usage
    picam.stop()

# %% [markdown]
# ### 4. The Function `colorPicker()`
#
# This function provides a **real-time color range selector** using OpenCV trackbars, allowing dynamic adjustment of HSV thresholds for object detection.
#
# - **Function Name**: `colorPicker`
# - **Returns**:
#   - `lower_bound` *(numpy.ndarray)* → Lower HSV threshold for color detection
#   - `upper_bound` *(numpy.ndarray)* → Upper HSV threshold for color detection
#
# - **Global Variables**:
#   - `latest_frame` → Holds the most recent frame from the camera thread
#   - `Frame_lock` → Ensures thread-safe access to the shared frame buffer
#
# - **Usage**:
#   - Creates a new OpenCV window with HSV trackbars:
#
#     ```python
#     cv2.namedWindow("Color_Picker")
#     cv2.createTrackbar("Lower Hue", "Color_Picker", 0, 179, nothing)
#     cv2.createTrackbar("Upper Hue", "Color_Picker", 179, 179, nothing)
#     ```
#   - Retrieves the latest camera frame safely with threading lock:
#
#     ```python
#     with Frame_lock:
#         if latest_frame is not None:
#             img = latest_frame.copy()
#         else:
#             continue
#     ```
#   - Converts the frame to HSV color space:
#
#     ```python
#     hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#     ```
#   - Reads current trackbar positions to set HSV bounds:
#
#     ```python
#     l_h = cv2.getTrackbarPos("Lower Hue", "Color_Picker")
#     u_h = cv2.getTrackbarPos("Upper Hue", "Color_Picker")
#     lower_bound = np.array([l_h, l_s, l_v])
#     upper_bound = np.array([u_h, u_s, u_v])
#     ```
#   - Applies color filtering and shows side-by-side results:
#
#     ```python
#     mask = cv2.inRange(hsv, lower_bound, upper_bound)
#     res = cv2.bitwise_and(img, img, mask=mask)
#     stacked = np.hstack((mask, img, res))
#     cv2.imshow("Color_Picker", cv2.resize(stacked, None, fx=0.4, fy=0.4))
#     ```
#   - Exits the loop and returns thresholds when the **'s' key** is pressed:
#
#     ```python
#     if cv2.waitKey(1) & 0xFF == ord('s'):
#         cv2.destroyAllWindows()
#         break
#     return lower_bound, upper_bound
#     ```

# %%
def colorPicker():
    def nothing(x):
        pass

    cv2.namedWindow("Color_Picker")
    cv2.createTrackbar("Lower Hue", "Color_Picker", 0, 179, nothing)
    cv2.createTrackbar("Lower Saturation", "Color_Picker", 0, 255, nothing)
    cv2.createTrackbar("Lower Value", "Color_Picker", 0, 255, nothing)
    cv2.createTrackbar("Upper Hue", "Color_Picker", 179, 179, nothing)
    cv2.createTrackbar("Upper Saturation", "Color_Picker", 255, 255, nothing)
    cv2.createTrackbar("Upper Value", "Color_Picker", 255, 255, nothing)

    while True:
        with Frame_lock:
            if latest_frame is not None:
                img = latest_frame.copy() # Copy the image from the camera thread
            else:
                continue # Skip the proces if no prame available 
        
        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        l_h = cv2.getTrackbarPos("Lower Hue", "Color_Picker")
        l_s = cv2.getTrackbarPos("Lower Saturation", "Color_Picker")
        l_v = cv2.getTrackbarPos("Lower Value", "Color_Picker")
        u_h = cv2.getTrackbarPos("Upper Hue", "Color_Picker")
        u_s = cv2.getTrackbarPos("Upper Saturation", "Color_Picker")
        u_v = cv2.getTrackbarPos("Upper Value", "Color_Picker")
        lower_bound = np.array([l_h, l_s, l_v])
        upper_bound = np.array([u_h, u_s, u_v])
        mask = cv2.inRange(hsv, lower_bound, upper_bound) 
        res = cv2.bitwise_and(img, img, mask=mask)
        mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGRA)
        stacked = np.hstack((mask, img, res))
        cv2.imshow("Color_Picker", cv2.resize(stacked, None, fx=0.4, fy=0.4))
        if cv2.waitKey(1) & 0xFF == ord('s'):
            cv2.destroyAllWindows()
            break
    return lower_bound, upper_bound

# %% [markdown]
# ### 5. The Function `avoidance_mode()`
#
# This function manages **obstacle avoidance behavior** when no tracked object is detected. It continuously monitors ultrasonic sensors and adjusts robot movement to prevent collisions.
#
# - **Function Name**: `avoidance_mode`
#
# - **Global Variables**:
#   - `Avoidance_mode` → Boolean flag to indicate if avoidance mode is active
#   - `object_detected` → Tracks if an object is currently detected for tracking
#   - `shutdown_event` → Event flag for safely terminating the thread
#   - `Avoidance_event` → Event flag to trigger obstacle avoidance behavior
#   - `Motor` → The `RPi_Robot_Hat_Lib` instance used for motor control
#   - `ultrasonic` → Ultrasonic sensor interface object
#   - `threshold` → Distance threshold in cm to trigger avoidance maneuvers
#   - `min_thresh_dist` → Minimum safe distance for emergency maneuvers
#
# - **Usage**:
#   - Runs continuously until shutdown event is set:
#
#     ```python
#     while not shutdown_event.is_set():
#     ```
#   - Activates obstacle avoidance only when `Avoidance_event` is set:
#
#     ```python
#     while Avoidance_event.is_set() and not shutdown_event.is_set():
#     ```
#   - Stops the robot before scanning for obstacles:
#
#     ```python
#     Motor.Brake()
#     left, front, right = ultrasonic.distances()
#     ```
#   - Checks sensor readings and applies conditional movement logic:
#     - **Front obstacle**:
#
#
#       ```python
#       if front <= min_thresh_dist:
#           Motor.Backward(Speed)
#           time.sleep(0.1)
#       ```
#     - **Both sides blocked**:
#
#       ```python
#       elif left < min_thresh_dist and right < min_thresh_dist:
#           Motor.Backward(Speed)
#           time.sleep(0.1)
#       ```
#     - **Left obstacle** → Turn right:
#
#       ```python
#       elif left < threshold:
#           Motor.move(speed=0, turn=rotation_speed)
#       ```
#     - **Right obstacle** → Turn left:
#
#       ```python
#       elif right < threshold:
#           Motor.move(speed=0, turn=-rotation_speed)
#       ```
#     - **No obstacle** → Move forward:
#
#       ```python
#       else:
#           Motor.Forward(Speed)
#       ```
#   - If no valid sensor data, the robot brakes and waits:
#
#     ```python
#     else:
#         print("No data received")
#         Motor.Brake()
#         time.sleep(1)
#     ```

# %%
def avoidance_mode():
    global Avoidance_mode,object_detected 
    # print("Avoidance Mode: ", Avoidance_mode)
    # print("shutdown_event: ", shutdown_event.is_set())
    # print("Avoidance_event: ", Avoidance_event.is_set())
    while not shutdown_event.is_set(): 
        # print("Avoidance Mode: ", Avoidance_mode)
        # print("shutdown_event: ", shutdown_event.is_set())
        # print("Avoidance_event: ", Avoidance_event.is_set())
        while Avoidance_event.is_set() and not shutdown_event.is_set():
            # with Frame_lock:
            #     if latest_frame is not None:
            #         img = latest_frame.copy()
            print("No object detected, switching to obstacle avoidance.")
            Speed = 40
            rotation_speed = 30
            Motor.Brake()
            left,front,right = ultrasonic.distances()
            if left is not None  and front is not None  and right is not None:
                print("left: {:.2f}".format(left))
                print("front: {:.2f}".format(front) )
                print("right: {:.2f}".format(right))
                if front < threshold or left < threshold or right < threshold:
                    if front < threshold:
                        if front <= min_thresh_dist:
                            Motor.Backward(Speed)
                            time.sleep(0.1)
                        elif left < min_thresh_dist and right < min_thresh_dist:
                            Motor.Backward(Speed)
                            time.sleep(0.1)
                        elif left < threshold:
                            Motor.move(speed=0, turn=rotation_speed)
                            time.sleep(0.1)
                        elif right < threshold:
                            Motor.move(speed=0, turn=-rotation_speed)
                            time.sleep(0.1)
                        else:
                            Motor.Backward(Speed)
                    elif left < threshold:
                        Motor.move(speed=0, turn=rotation_speed)
                        time.sleep(0.1)
                    elif right < threshold:
                        Motor.move(speed=0, turn=-rotation_speed)
                        time.sleep(0.1)
                else:
                    Motor.Forward(Speed)
            else:
                print("No data received")
                Motor.Brake()
                time.sleep(1)
            time.sleep(0.5)
        else:
            # print("Avoidance event is not set")
            pass

# %% [markdown]
# ### 6. The Function `main()`
#
# This function manages the **main program loop**, combining **object tracking** with color detection and **obstacle avoidance** using ultrasonic sensors.
#
# - **Function Name**: `main`
#
# - **Global Variables**:
#   - `Tracking_mode` → Boolean flag indicating object tracking is active
#   - `Avoidance_mode` → Boolean flag indicating obstacle avoidance is active
#   - `object_detected` → Boolean flag for object presence
#   - `latest_frame` → Latest frame captured from the camera thread
#   - `shutdown_event` → Event flag for shutting down all threads safely
#   - `Frame_lock` → Synchronization lock for accessing frames
#   - `Motor` → `RPi_Robot_Hat_Lib` instance for motor control
#   - `picam` → `Picamera2` instance for camera capture
#   - `Avoidance_event` → Event flag to trigger avoidance mode
#   - `MIN_AREA_THRESHOLD` → Minimum contour area to qualify as valid object
#
# - **Usage**:
#   - **Initialize color detection bounds** using the `colorPicker()` function:
#
#     ```python
#     lower_bound, upper_bound = colorPicker()
#     cv2.destroyAllWindows()
#     ```
#
#   - **Main loop execution** until shutdown:
#
#     ```python
#     while not shutdown_event.is_set():
#     ```
#
#   - **Acquire latest frame safely** from the camera thread:
#
#     ```python
#     with Frame_lock:
#         if latest_frame is not None:
#             img = latest_frame.copy()
#         else:
#             print("No frame available")
#             break
#     ```
#
#   - **Convert to HSV** and apply color mask:
#
#     ```python
#     hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
#     mask = cv2.inRange(hsv, lower_bound, upper_bound)
#     contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     ```
#
#   - **Object Detection & Tracking**:
#     - Select the **largest contour** and calculate area.
#     - If contour area > threshold, enter tracking mode:
#
#       ```python
#       x, y, w, h = cv2.boundingRect(largest_contour)
#       cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
#       cv2.circle(img, (x + w // 2, y + h // 2), 5, (0, 0, 255), -1)
#       ```
#     - Calculate **object center coordinates**:
#
#       ```python
#       center_x = int(x + w // 2)
#       center_y = int(y + h // 2)
#       ```
#
#   - **Motor Control Logic** based on object position:
#     - Object in center zone → Move forward
#
#       ```python
#       if 320 <= center_x <= 400:
#           Motor.Forward(40)
#       ```
#     - Object left zone → Turn left
#
#       ```python
#       if 50 < center_x < 320:
#           Motor.move(speed=0, turn=-30)
#       ```
#     - Object right zone → Turn right
#
#       ```python
#       if 400 < center_x < 600:
#           Motor.move(speed=0, turn=30)
#       ```
#     - Object too close → Stop robot
#
#       ```python
#       if (370 < center_y < 400) or area > 30000:
#           Motor.Brake()
#           print("Object Found")
#       ```
#
#   - **Switching Modes**:
#     - If no valid contour or small area → Switch to avoidance mode
#
#       ```python
#       Avoidance_mode = True
#       Avoidance_event.set()
#       print("Switching to Avoidance mode")
#       ```
#
#   - **Visualization**:
#     Displays either **Tracking Window** or **Obstacle Avoidance Window** depending on active mode.
#
#   - **Exit Condition**:
#     Program shuts down cleanly when user presses **`q`**:
#
#     ```python
#     if cv2.waitKey(1) == ord('q'):
#         shutdown_event.set()
#         Motor.cleanup()
#         picam.stop()
#         cv2.destroyAllWindows()
#     ```

# %%
def main():
    global Tracking_mode, Avoidance_mode, object_detected
    lower_bound, upper_bound = colorPicker()  # Get color bounds from the color picker
    cv2.destroyAllWindows()

    while not shutdown_event.is_set():
        # 1. Run color tracker to check for the object
        with Frame_lock:
            if latest_frame is not None:
                img = latest_frame.copy()
            else:
                print("No frame available")
                break  # Skip if no frame available

        hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
        mask = cv2.inRange(hsv, lower_bound, upper_bound)
        contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        object_detected = False
        if contours:
            contours = sorted(contours, key=cv2.contourArea, reverse=True)
            largest_contour = contours[0] 
            area = cv2.contourArea(largest_contour)
            if area > MIN_AREA_THRESHOLD:
                if Avoidance_mode:
                    cv2.destroyWindow("Obstacle Avoidance")
                    Tracking_mode = True
                    Avoidance_mode = False
                    Avoidance_event.clear()

                cv2.putText(img, "Object Tracking Mode", (10, 30), cv2.FONT_HERSHEY_COMPLEX, 0.7, (0, 0, 255), 2)
                object_detected = True  # Object detected
                x, y, w, h = cv2.boundingRect(largest_contour)
                cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)
                cv2.circle(img, (x + w // 2, y + h // 2), 5, (0, 0, 255), -1)
                cv2.putText(img, "Object", (x, y - 10), cv2.FONT_HERSHEY_COMPLEX, 0.7, (0, 255, 0), 2)
                cv2.putText(img, "Area: " + str(area), (x, y + h + 20), cv2.FONT_HERSHEY_COMPLEX, 0.7, (0, 255, 0), 2)
                cv2.putText(img, "Center of Object: (" + "x: " + str(x + w // 2) + ", " + "y: " + str(y + h // 2) + ")", (10, 60), cv2.FONT_HERSHEY_COMPLEX, 0.7, (0, 255, 0), 2)
                

                center_x = int(x + w // 2)
                center_y = int(y + h // 2)

                # Motor control based on object's center position
                if 80 < center_y < 440:
                    if 50 < center_x < 320:
                        print("Turn Left")
                        Motor.move(speed=0, turn=-30)
                    elif 400 < center_x < 600:
                        print("Turn Right")
                        Motor.move(speed=0, turn=30)
                    elif 320 <= center_x <= 400:
                        Motor.Forward(40)
                        print("Centered")
                    else:
                        Motor.Brake()
                if  (370 < center_y < 400) or area > 30000:
                    Motor.Brake()
                    print("Object Found")
                    cv2.putText(img, "Object Found", (200, 200), cv2.FONT_HERSHEY_COMPLEX, 1, (0, 0, 255), 4)
                else:
                    object_detected = False
                    if not Avoidance_mode:
                        Avoidance_mode = True
                        Avoidance_event.set()
                        print("Switching to Avoidance mode")
                cv2.imshow("Tracking", img)
            else:
                cv2.destroyWindow("Tracking")
                object_detected = False
                if not Avoidance_mode:
                    Avoidance_mode = True
                    Avoidance_event.set()
                    print("Switching to Avoidance mode")
                cv2.putText(img, "Obstacle Avoidance Mode", (10, 30), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255, 0, 0), 2)
                cv2.imshow("Obstacle Avoidance", img)
        else:
            if not Avoidance_mode:
                Avoidance_mode = True
                Avoidance_event.set()
                print("Switching to Avoidance mode")
            if Tracking_mode:
                cv2.destroyWindow("Tracking")
                Tracking_mode = False
            cv2.putText(img, "Obstacle Avoidance Mode", (10, 30), cv2.FONT_HERSHEY_COMPLEX, 0.7, (255, 0, 0), 2)
            cv2.imshow("Obstacle Avoidance", img)

        # Check for user input to quit the program
        if cv2.waitKey(1) == ord('q'):
            print("Shutting down...")
            cv2.destroyAllWindows()
            Motor.cleanup()
            picam.stop()
            print("Program Terminated \n Exiting....")
            shutdown_event.set()

# %% [markdown]
# ### 7. The Program Entry Point `if __name__ == '__main__':`
#
# This block defines the **entry point** of the program. It starts the required threads, executes the main loop, and ensures proper cleanup when the program ends.
#
# - **Function Name**: `__main__` (entry point)
#
# - **Global Variables**:
#   - `camera_thread` → Thread running the `camera()` function to continuously capture frames
#   - `Avoidance_thread` → Thread running the `avoidance_mode()` function for obstacle handling
#   - `shutdown_event` → Event flag to safely stop all running threads
#   - `Avoidance_event` → Event flag controlling obstacle avoidance loop
#   - `Motor` → `RPi_Robot_Hat_Lib` instance for robot control
#   - `picam` → `Picamera2` object for video capture
#
# - **Usage**:
#   - **Thread Initialization**:
#     Starts camera and avoidance mode in separate threads to allow parallel execution:
#
#     ```python
#     camera_thread = threading.Thread(target=camera)
#     Avoidance_thread = threading.Thread(target=avoidance_mode)
#
#     camera_thread.start()
#     Avoidance_thread.start()
#     ```
#
#   - **Main Execution**:
#     Calls the `main()` loop which switches between **object tracking** and **obstacle avoidance**:
#
#     ```python
#     main()
#     ```
#
#   - **Interrupt Handling**:
#     Ensures the program exits gracefully when the user presses **CTRL+C**:
#
#     ```python
#     except KeyboardInterrupt:
#         print("KeyboardInterrupt")
#     ```
#
#   - **Final Cleanup**:
#     Safely shuts down all components and threads:
#
#     ```python
#     shutdown_event.set()
#     Avoidance_event.clear()
#     camera_thread.join()
#     cv2.destroyAllWindows()
#     Motor.cleanup()
#     picam.stop()
#     print("Program Terminated \n Exiting....")
#     exit()
#     ```

# %%
try:
    if __name__ == '__main__':
        camera_thread = threading.Thread(target=camera)
        Avoidance_thread = threading.Thread(target=avoidance_mode) 

        camera_thread.start()
        Avoidance_thread.start()

        main()
except KeyboardInterrupt:
    print("KeyboardInterrupt")
finally:
    shutdown_event.set()
    Avoidance_event.clear()
    camera_thread.join()
    cv2.destroyAllWindows()
    Motor.cleanup()
    picam.stop()
    print("Program Terminated \n Exiting....")
    exit()
