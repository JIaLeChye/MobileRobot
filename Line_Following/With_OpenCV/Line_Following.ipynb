# %% [markdown]
# # Line Following using OpenCV
#
# ## Overview
# This line-following system uses **computer vision** to detect and follow a black line in real time with OpenCV.
# The robot processes the camera feed, identifies the line’s contour/centroid, and continuously adjusts motor commands for precise tracking.
#
# **Full source code:** [Line_Following.py](Line_Following.py)
#
# ## Features
# - **Computer Vision Pipeline** – Real-time frame processing with OpenCV
# - **HSV Color Filtering** – Robust black-line segmentation under varying lighting
# - **Contour & Centroid Analysis** – Line shape detection and center tracking via image moments
# - **Edge Detection** – Optional Canny edges to enhance line visibility
# - **Servo Camera Control** – Pan/tilt (gimbal) support for optimal view framing
# - **Dynamic Movement Control** – Speed/turn rates adapt to line position error
#
# ## Libraries Used
# - **Picamera2** – Raspberry Pi camera capture
# - **libcamera** – Low-level camera controls/configuration
# - **OpenCV (`cv2`)** – Image processing and computer vision
# - **NumPy** – Array operations and numerical utilities
# - **time** – Timing and delays
# - **RPi_Robot_Hat_Lib** – Custom library for motor control

# %% [markdown]
# ## System Architecture and Algorithm
#
# ### Computer Vision Pipeline
# 1. **Image Capture** – Continuous frame capture from **Picamera2**
# 2. **Color Space Conversion** – Convert **RGB → HSV** for stable detection
# 3. **Color Filtering** – Apply HSV thresholds to isolate **black lines**
# 4. **Edge Detection** – Use **Canny edges** to highlight line boundaries
# 5. **Contour Detection** – Extract contours representing line geometry
# 6. **Centroid Calculation** – Compute the line’s **center point** using image moments
# 7. **Motion Control** – Adjust robot motion based on centroid offset
#
# ### Navigation Algorithm
# - **Line Detection** – Black line isolated via HSV thresholds
# - **Position Analysis** – Centroid `(cx)` used as reference for navigation
# - **Decision Making** – Three-zone system:
#   - **Left Zone**: `cx ≥ 350` → Turn left
#   - **Center Zone**: `300 < cx < 350` → Move forward
#   - **Right Zone**: `cx < 300` → Turn right
#
# ### Hardware Integration
# - **Pan–Tilt Control** – Servo motors adjust camera angle dynamically
# - **Motor Control** – Movement commands issued via **RPi_Robot_Hat_Lib**
# - **Real-Time Loop** – Frames processed continuously for instant corrections

# %% [markdown]
# ## Let's start Coding !
#
# ### 1. Import Required Libraries
# Import all necessary libraries for computer vision, camera control, and robot movement:
#
# - `Picamera2` → Camera interface for Raspberry Pi
# - `controls`, `Transform` *(from libcamera)* → Camera configuration and orientation control
# - `cv2` *(OpenCV)* → Image processing and computer vision
# - `numpy` → Array operations for image data
# - `time` → Timing functions and delays
# - `RobotController` *(custom)* → Motor and servo control for robot hardware

# %%
from picamera2 import Picamera2
from libcamera import controls, Transform 
import cv2
import numpy as np
import time
from RPi_Robot_Hat_Lib import RobotController

# %% [markdown]
# ### 2. The Function `init()`
#
# This function initializes the **motor controller**, **encoder**, and **camera preview** for the line following system.
#
# - **Function Name**: `init`
#
# - **Parameters**:
#   - *None*
#
# - **Returns**:
#   - `picamera2.Picamera2` → The initialized Picamera2 object
#
# - **Global Variables**:
#     - `picam2`: The Raspberry Pi Camera Library
#     - `horizontal`: The servo number for horizontal movement of the pan-tilt camera hat
#     - `vertical` : The servo number for vertical movement of the pan-tilt camera hat
#     - `frame_center`: The center value of the captured frame
#     - `Motor`: The RPi_Robot_Hat_Lib Library
#     ```python
#     global picam2, horizontal, vertical, frame_center, Motor
#     ```
#
# - **Usage**:
#   - Creates and initializes the **RPi_Robot_Hat_Lib** Library and save to the variable `Motor`
#     ```python
#     Motor = RobotController()
#     ```
#   - Sets up the **Pan-Tilt servos** for camera orientation  \
#     ```python
#     vertical = 1
#     horizontal = 2
#     Motor.set_servo(vertical, 90)
#     Motor.set_servo(horizontal,180 )
#     ```
#
#   - Configures the **Picamera2** with preview resolution `(640x480)`
#     ```python
#     picam2 = Picamera2()
#     config = picam2.create_preview_configuration(main={"format": 'RGB888', "size": (640, 480)},transform=Transform(vflip=1))
#     picam2.configure(config)
#     picam2.start()  # Start camera preview
#     ## Continous Auto Focus
#     ```
#   - Enables **continuous auto-focus** mode
#     ```python
#     picam2.set_controls({"AfMode": controls.AfModeEnum.Continuous})
#     ```
#
#   - Calculates and stores the **frame center coordinates**
#     ```python
#     frame_center = (picam2.preview_configuration.main.size[0] // 2 ,
#                     picam2.preview_configuration.main.size[1] // 2)
#     ```
#
#   - Returns the `Picamera2` object for use in the main loop
#     ```python
#     return picam2
#     ```

# %%
def init():
    """
    Initialize the Motor, Encoder, and camera preview.

    Returns
    -------
    picamera2.Picamera2
        The initialized Picamera2 object.
    """
    global picam2, horizontal, vertical, frame_center, Motor
    # Initialise the Motor
    Motor = RobotController()
    


    # Set PanTilt and servo HAT
    vertical = 1
    horizontal = 2
    Motor.set_servo(vertical, 90)
    Motor.set_servo(horizontal,180 )

    # Set preview configuration (modify resolution as needed)
    picam2 = Picamera2()
    config = picam2.create_preview_configuration(main={"format": 'RGB888', "size": (640, 480)},transform=Transform(vflip=1))
    picam2.configure(config)
    picam2.start()  # Start camera preview
    ## Continous Auto Focus 
    picam2.set_controls({"AfMode": controls.AfModeEnum.Continuous})

    frame_center = (picam2.preview_configuration.main.size[0] // 2 ,
                    picam2.preview_configuration.main.size[1] // 2)


    return picam2

# %% [markdown]
# ### 3. The Function `main()`
#
# This function performs **object tracking, line detection, and motor control** using OpenCV and the Raspberry Pi Camera.
#
# - **Function Name**: `main`
#
# - **Global Variables**:
#   - `picam2`: The Picamera2 object used to capture live frames
#   - `frame_center`: The center coordinates of the captured frame
#   - `Motor`: The `RPi_Robot_Hat_Lib` motor controller instance
#     ```python
#     global picam2, frame_center, Motor
#     ```
# - **Usage**:
#   - Initialize system components by calling `init()`
#     ```python
#     init()
#     ```
#   - Start the **main loop** to continuously capture frames
#     ```python
#     while True:
#         frame = picam2.capture_array()\
#     ```
#   - Convert the captured frame from **RGB to HSV** for color filtering
#     ```python
#     hsv_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)
#     ```
#   - Apply an HSV mask to detect black lines
#     ```python
#     Black_lower = np.array([0,0,0], dtype="uint8")
#     Black_upper = np.array([179, 255, 118], dtype="uint8")
#     Blacklines = cv2.inRange(frame, Black_lower, Black_upper)
#     ```
#   - Perform **Canny edge detection**
#     ```python
#     canny_edges = cv2.Canny(Blacklines, 50, 150)
#     ```
#   - Find contours of the detected black lines
#     ```python
#     contours, _ = cv2.findContours(Blacklines, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     ```
#   - Identify and draw the **largest contour** for tracking
#     ```python
#     largeset = max(contours, key=cv2.contourArea)
#     cv2.drawContours(frame, largeset, 0, (0,0,255), 5)
#     ```
#   - Calculate the centroid `(cx, cy)` of the contour using image moments
#     ```python
#     M = cv2.moments(largeset)
#     cx = int(M["m10"] / M["m00"]) if M["m00"] != 0 else 0
#     cy = int(M["m01"] / M["m00"]) if M["m00"] != 0 else 0
#     ```
#   - Display centroid offset on the frame
#     ```python
#     cv2.putText(frame, f" Offset: X = {cx}, Y: = {cy}",
#         (10,20), cv2.FONT_HERSHEY_COMPLEX, 0.7, (0,255,255), 2 )
#     ```
#   - Control robot movement based on centroid position:
#     - **Left zone**:
#     ```python
#     if cx >= 350:
#         Motor.move(speed=0, turn=-30)
#     ```
#     - **On track**:
#     ```python
#     if cx < 350 and cx > 300:
#         Motor.Forward(40)
#     ```
#     - **Right zone**:
#     ```python
#     if cx < 300:
#         Motor.move(speed=0, turn=30)
#     ```
#   - If no line is detected, stop the robot
#     ```python
#     Motor.Brake()
#     ```
#   - Display the processed frames
#     ```python
#     cv2.imshow("Black Lines", Blacklines)
#     cv2.imshow("Edge Detection", canny_edges)
#     cv2.imshow("Main", frame)
#     ```
# - Provide exit condition (`q` key)
#  ```python
#     key = cv2.waitKey(1) & 0xFF
#     if key == ord('q'):
#         break
# ```

# %%
def main():
    """
    main fucntion is to perform object tracking and motor control 
    """
    global picam2, frame_center, Motor

    init()

    while True:
        frame = picam2.capture_array()
        
        
        hsv_frame = cv2.cvtColor(frame, cv2.COLOR_RGB2HSV)
        Black_lower = np.array([56,22,27], dtype = "uint8")
        Black_upper = np.array([179, 255, 255], dtype = "uint8")
        Blacklines = cv2.inRange(frame, Black_lower, Black_upper)
               
                
        canny_edges = cv2.Canny(Blacklines, 50, 150)
        
        contours, _  = cv2.findContours(Blacklines, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if len(contours) > 0 :
            for contour in contours:
                cv2.drawContours(frame, [contour] , 0 , (0,255,0), 2)
                
            
        frame_offset = (0,0)
        if len(contours) > 0:
            largeset = max(contours, key = cv2.contourArea)
            cv2.drawContours(frame, largeset , 0 , (0,0,255), 5)
            
            M = cv2.moments(largeset)
            cx = int(M["m10"] / M["m00"]) if M["m00"] != 0 else 0
            cy = int(M["m01"] / M["m00"]) if M["m00"] != 0 else 0
            cv2.putText(frame, f" Offset: X = {cx}, Y: = {cy}",
                        (10,20), cv2.FONT_HERSHEY_COMPLEX, 0.7, (0,255,255), 2 )
            
            if cx >= 350:
                print("Going Left")
                Motor.move(speed=0, turn=-15)
            
            if cx < 350 and cx > 300:
                print("On track")
                Motor.Forward(20)
            if cx < 300:
                print("Going Right")
                Motor.move(speed =0 , turn=15)

            
            cv2.circle(frame, (cx,cy),5,(255,255,0),-1)
        else:
            Motor.Brake()
            print("Nothing Detected")


        cv2.imshow("Black Lines", Blacklines)
        cv2.imshow("Edge Detection", canny_edges)
        cv2.imshow("Main", frame) 
    
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break

# %% [markdown]
# ### 4. The Execution Block `if __name__ == "__main__":`
#
# This block ensures that the program runs the **main function** only when executed directly, and handles safe shutdown on exit.
#
# - **Function Name**: *Execution block*
#
# - **Usage**:
#   - Starts the program by calling the `main()` function when the script is executed directly
#     ```python
#     if __name__ == '__main__':
#         main()
#     ```
#
#   - Handles **KeyboardInterrupt (Ctrl+C)** gracefully by stopping and cleaning up motors
#     ```python
#     except KeyboardInterrupt:
#         Motor.Brake()
#         Motor.cleanup()
#     ```
#
#   - Ensures safe shutdown in the `finally` block by:
#     - Braking and cleaning up motors
#     - Closing OpenCV windows
#     - Stopping the camera
#     - Exiting the program
#     ```python
#     finally:
#         Motor.Brake()
#         Motor.cleanup()
#         cv2.destroyAllWindows()
#         picam2.stop()
#         exit()
#     ```

# %%
try:
    if __name__ == '__main__': 
        main()
        
except KeyboardInterrupt:
    Motor.Brake()
    Motor.cleanup()

finally:
    Motor.Brake()
    Motor.cleanup()
    cv2.destroyAllWindows()
    picam2.stop()
    exit()
